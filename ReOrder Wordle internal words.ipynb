# %%
import sys, os
from os.path import join as pJoin

sys.path.append(pJoin(os.getcwd(), '../lib'))

# from words import allowedGuesses, answerWords
import csv

with open('wordle-words/answer-words.github.txt') as inFD:
    answerWords = inFD.read().splitlines()

with open('wordle-words/allowed-guesses.wordle-code.txt') as inFD:
    allowedGuesses = inFD.read().splitlines()

wordFreq = {}

for word, count in csv.reader(open('google-words/unigram_freq.csv')):
    wordFreq[word] = count

# Process the Answer Words
newAnswerWordsByFreq = {}
with open('wordle-words/answer-words.github.sorted.by.freq.txt', 'wt') as outFD:
    missingWords = 0
    for word in answerWords:
        try:
            newAnswerWordsByFreq[word] = wordFreq[word]
        except KeyError:
            newAnswerWordsByFreq[word] = 0
            print(f'Missing word: {word}')
            missingWords += 1

    print(f"Missing words in Answer Words: {missingWords}")
    # lettersToTry = [x[0] for x in sorted(lettersToTryDict.items(), key=lambda x: x[1], reverse=True)]
    for word, freq in sorted(newAnswerWordsByFreq.items(), key=lambda x: int(x[1]), reverse=True):
        # print(word, freq)
        print(word, file=outFD)

# Process the Allowed Guesses Words
with open('wordle-words/allowed-guesses.wordle-code.sorted.by.freq.txt', 'wt') as outFD:
    missingWords = 0
    for word in allowedGuesses:
        try:
            newAnswerWordsByFreq[word] = wordFreq[word]
        except KeyError:
            newAnswerWordsByFreq[word] = 0
            # print(f'Missing word: {word}')
            missingWords += 1

    print(f"Missing words in Allowed Guesses: {missingWords}")
    # lettersToTry = [x[0] for x in sorted(lettersToTryDict.items(), key=lambda x: x[1], reverse=True)]
    for word, freq in sorted(newAnswerWordsByFreq.items(), key=lambda x: int(x[1]), reverse=True):
        # print(word, freq)
        print(word, file=outFD)
# Out:
# Missing word: wooer
# Missing words in Answer Words: 1
# Missing words in Allowed Guesses: 6101
